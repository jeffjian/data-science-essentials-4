# %%
import pandas as pd

# %%
hospital_df = pd.read_csv("/Users/jeffreyj/Documents/GitHub/data-science-essentials-4/data/Hospitals.csv")

# %% [markdown]
# The starting index begins from 0; the ending index terminates at len(pd)+1

# %% [markdown]
# There are 7596 rows and 34 columns

# %%
print(hospital_df)
# Out:
#                  X             Y  OBJECTID         ID  \
# 0    -1.331889e+07  4.346975e+06         1    5793230
# 1    -1.322651e+07  4.049626e+06         2   53391362
# 2    -1.315620e+07  4.031978e+06         3   11190023
# 3    -1.317190e+07  4.041752e+06         4   17090028
# 4    -1.313208e+07  4.037270e+06         5   23691706
# ...            ...           ...       ...        ...
# 7591 -8.566905e+06  4.728815e+06      7607  183520904
# 7592 -1.219624e+07  3.676931e+06      7608  192185607
# 7593 -8.084677e+06  5.094112e+06      7609  196706457
# 7594 -8.522423e+06  4.718512e+06      7610  191021401
# 7595 -1.244921e+07  4.976468e+06      7611  196784108
#
#                                                    NAME  \
# 0                       CENTRAL VALLEY GENERAL HOSPITAL
# 1     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                     EAST LOS ANGELES DOCTORS HOSPITAL
# 3             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# ...

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7596 non-null   float64
#  1   Y           7596 non-null   float64
#  2   OBJECTID    7596 non-null   int64
#  3   ID          7596 non-null   int64
#  4   NAME        7596 non-null   object
#  5   ADDRESS     7596 non-null   object
#  6   CITY        7596 non-null   object
#  7   STATE       7596 non-null   object
#  8   ZIP         7596 non-null   int64
#  9   ZIP4        7596 non-null   object
#  10  TELEPHONE   7596 non-null   object
#  11  TYPE        7596 non-null   object
#  12  STATUS      7596 non-null   object
#  13  POPULATION  7596 non-null   int64
#  14  COUNTY      7596 non-null   object
#  15  COUNTYFIPS  7596 non-null   object
#  16  COUNTRY     7596 non-null   object
#  17  LATITUDE    7596 non-null   float64
#  18  LONGITUDE   7596 non-null   float64
# ...

# %%
hospital_df.head(10)
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
# 2 -1.315620e+07  4.031978e+06         3  11190023
# 3 -1.317190e+07  4.041752e+06         4  17090028
# 4 -1.313208e+07  4.037270e+06         5  23691706
# 5 -1.315222e+07  4.009980e+06         6  25190712
# 6 -1.313488e+07  4.048794e+06         7  30791016
# 7 -1.315109e+07  4.035446e+06         8  30891754
# 8 -1.317534e+07  4.005182e+06         9  47090505
# 9 -1.308604e+07  4.009762e+06        10   9092879
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
# 5                   LAKEWOOD REGIONAL MEDICAL CENTER
# ...

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7596 non-null   float64
#  1   Y           7596 non-null   float64
#  2   OBJECTID    7596 non-null   int64
#  3   ID          7596 non-null   int64
#  4   NAME        7596 non-null   object
#  5   ADDRESS     7596 non-null   object
#  6   CITY        7596 non-null   object
#  7   STATE       7596 non-null   object
#  8   ZIP         7596 non-null   int64
#  9   ZIP4        7596 non-null   object
#  10  TELEPHONE   7596 non-null   object
#  11  TYPE        7596 non-null   object
#  12  STATUS      7596 non-null   object
#  13  POPULATION  7596 non-null   int64
#  14  COUNTY      7596 non-null   object
#  15  COUNTYFIPS  7596 non-null   object
#  16  COUNTRY     7596 non-null   object
#  17  LATITUDE    7596 non-null   float64
#  18  LONGITUDE   7596 non-null   float64
# ...

# %%
new_hospital_df = hospital_df.drop(["X","Y","OBJECTID","ID","ZIP","ZIP4","TELEPHONE","STATUS","COUNTRY","NAICS_CODE","SOURCE","SOURCEDATE","VAL_METHOD","VAL_DATE","WEBSITE","STATE_ID","ALT_NAME","ST_FIPS","OWNER","TTL_STAFF","TRAUMA","HELIPAD"],axis=1)

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7596 non-null   float64
#  1   Y           7596 non-null   float64
#  2   OBJECTID    7596 non-null   int64
#  3   ID          7596 non-null   int64
#  4   NAME        7596 non-null   object
#  5   ADDRESS     7596 non-null   object
#  6   CITY        7596 non-null   object
#  7   STATE       7596 non-null   object
#  8   ZIP         7596 non-null   int64
#  9   ZIP4        7596 non-null   object
#  10  TELEPHONE   7596 non-null   object
#  11  TYPE        7596 non-null   object
#  12  STATUS      7596 non-null   object
#  13  POPULATION  7596 non-null   int64
#  14  COUNTY      7596 non-null   object
#  15  COUNTYFIPS  7596 non-null   object
#  16  COUNTRY     7596 non-null   object
#  17  LATITUDE    7596 non-null   float64
#  18  LONGITUDE   7596 non-null   float64
# ...

# %%
new_hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        7596 non-null   object
#  1   ADDRESS     7596 non-null   object
#  2   CITY        7596 non-null   object
#  3   STATE       7596 non-null   object
#  4   TYPE        7596 non-null   object
#  5   POPULATION  7596 non-null   int64
#  6   COUNTY      7596 non-null   object
#  7   COUNTYFIPS  7596 non-null   object
#  8   LATITUDE    7596 non-null   float64
#  9   LONGITUDE   7596 non-null   float64
#  10  NAICS_DESC  7596 non-null   object
#  11  BEDS        7596 non-null   int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 712.2+ KB

# %%
new_hospital_df["TYPE"].value_counts()
# Out:
# GENERAL ACUTE CARE    4481
# CRITICAL ACCESS       1027
# PSYCHIATRIC            759
# LONG TERM CARE         431
# REHABILITATION         378
# MILITARY               216
# SPECIAL                145
# CHILDREN               130
# WOMEN                   20
# CHRONIC DISEASE          9
# Name: TYPE, dtype: int64

# %% [markdown]
# The most common type of hospital is General Acute Care

# %%
nashville_hospital = new_hospital_df.loc[(new_hospital_df["CITY"]=="NASHVILLE")]

# %%
nashville_tennessee_hospital = nashville_hospital.loc[nashville_hospital["STATE"]=="TN"]

# %%
print(nashville_tennessee_hospital)
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# ...

# %%
nashville_tennessee_hospital
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# ...

# %% [markdown]
# The "BEDS" column is identical to the population column; it's possible that all of the beds are full, and would normally count the number of open beds there are at that location

# %%
tennessee_hospital = new_hospital_df.loc[new_hospital_df["STATE"]=="TN"]

# %%
tennessee_hospital
# Out:
#                                           NAME                    ADDRESS  \
# 515       STARR REGIONAL MEDICAL CENTER ETOWAH      886 HIGHWAY 411 NORTH
# 535                    JACKSON COUNTY HOSPITAL         620 HOSPITAL DRIVE
# 536                    MAURY REGIONAL HOSPITAL       1224 TROTWOOD AVENUE
# 537   WEST TENNESSEE HEALTHCARE NORTH HOSPITAL         367 HOSPITAL BLVD.
# 540                HENRY COUNTY MEDICAL CENTER           301 TYSON AVENUE
# ...                                        ...                        ...
# 6810             TRISTAR PORTLAND MEDICAL PARK             105 RED BUD DR
# 6811         TRISTAR STONECREST MEDICAL CENTER   200 STONECREST BOULEVARD
# 6812           UNICOI COUNTY MEMORIAL HOSPITAL        100 GREENWAY CIRCLE
# 6813            VANDERBILT UNIVERSITY HOSPITAL  1211 MEDICAL CENTER DRIVE
# 7362                    UNICOI COUNTY HOSPITAL      2030 TEMPLE HILL ROAD
#
#             CITY STATE                TYPE  POPULATION      COUNTY COUNTYFIPS  \
# ...

# %%
type(tennessee_hospital)
# Out:
# pandas.core.frame.DataFrame

# %%
tennessee_hospital["COUNTY"].value_counts()
# Out:
# SHELBY        23
# DAVIDSON      15
# HAMILTON      13
# KNOX          11
# WASHINGTON     6
#               ..
# HICKMAN        1
# LAWRENCE       1
# BENTON         1
# HAYWOOD        1
# TROUSDALE      1
# Name: COUNTY, Length: 80, dtype: int64

# %% [markdown]
# Shelby County in TN has the most hospitals

# %%
tennessee_hospital["TYPE"].value_counts()
# Out:
# GENERAL ACUTE CARE    125
# REHABILITATION         12
# LONG TERM CARE         11
# CRITICAL ACCESS         8
# PSYCHIATRIC             5
# MILITARY                4
# CHILDREN                3
# WOMEN                   3
# Name: TYPE, dtype: int64

# %% [markdown]
# according to Google, 22 counties in TN have no hospitals, but   95-80+1 = 14(?) counties without hospitals

# %%
hospitals_df.shape
# Out:
# (7596, 34)

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
new_hospital_df["TYPE"].unique()
# Out:
# array(['GENERAL ACUTE CARE', 'PSYCHIATRIC', 'CHILDREN', 'LONG TERM CARE',
#        'CRITICAL ACCESS', 'REHABILITATION', 'MILITARY', 'WOMEN',
#        'SPECIAL', 'CHRONIC DISEASE'], dtype=object)

# %%
help(pd.unique)
# Out:
# Help on function unique in module pandas.core.algorithms:
#
# unique(values)
#     Hash table-based unique. Uniques are returned in order
#     of appearance. This does NOT sort.
#
#     Significantly faster than numpy.unique. Includes NA values.
#
#     Parameters
#     ----------
#     values : 1d array-like
#
#     Returns
#     -------
#     numpy.ndarray or ExtensionArray
#
#         The return can be:
#
#         * Index : when the input is an Index
#         * Categorical : when the input is a Categorical dtype
#         * ndarray : when the input is a Series/ndarray
#
#         Return numpy.ndarray or ExtensionArray.
#
#     See Also
#     --------
#     Index.unique
#     Series.unique
#
#     Examples
#     --------
#     >>> pd.unique(pd.Series([2, 1, 3, 3]))
#     array([2, 1, 3])
#
#     >>> pd.unique(pd.Series([2] + [1] * 5))
#     array([2, 1])
#
#     >>> pd.unique(pd.Series([pd.Timestamp('20160101'),
#     ...                     pd.Timestamp('20160101')]))
# ...

# %%
new_hospital_df.loc[(new_hospital_df["CITY"]=="NASHVILLE")&(new_hospital_df["STATE"]=="TN")]
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# ...

# %%
tennessee_hospital["COUNTY"].nunique()
# Out:
# 80
